# %% [markdown]
# <a href="https://colab.research.google.com/github/vyshu89100/Demand_Prediction/blob/main/data_science_kitchen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the drive module
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import pandas
import pandas as pd

# Read the file from Google Drive
file = pd.read_csv('/content/drive/MyDrive/Datasets/my kitchen ds.csv')
file.head(7)
# Out:
#                                                 name   main_category  \
# 0  Kitchwell Kitchen Accessories Items | 1100 ML ...  home & kitchen
# 1  Bulfyss Multipurpose 45cm x 5m Super Strong EV...  home & kitchen
# 2  Pigeon By Stovekraft All in One Super Cooker A...  home & kitchen
# 3  STAR WORK Muslin Cloth 1 X 1.2 Meter Cotton fo...  home & kitchen
# 4  Zuvexa 3 Slot Knife Sharpener Professional Kit...  home & kitchen
# 5  Prestige Aluminium Omega Select Plus Non Stick...  home & kitchen
# 6  Prestige Deluxe Alpha Svachh Stainless Steel S...  home & kitchen
#
#        sub_category                                              image  \
# 0  Kitchen & Dining  https://m.media-amazon.com/images/I/81Jf-Gz8hO...
# 1  Kitchen & Dining  https://m.media-amazon.com/images/I/61iCTMUVtE...
# 2  Kitchen & Dining  https://m.media-amazon.com/images/I/51OhGq1Y8T...
# 3  Kitchen & Dining  https://m.media-amazon.com/images/I/81fTL+GEuL...
# 4  Kitchen & Dining  https://m.media-amazon.com/images/I/71p6rKdaoq...
# 5  Kitchen & Dining  https://m.media-amazon.com/images/I/71J93Wb4DF...
# 6  Kitchen & Dining  https://m.media-amazon.com/images/I/51yA9EZIhY...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Kitchwell-Accessories-Co...     4.3            37
# 1  https://www.amazon.in/Bulfyss-Multipurpose-Tex...     4.3         6,484
# 2  https://www.amazon.in/Pigeon-Stovekraft-Cerami...       4         4,321
# 3  https://www.amazon.in/STAR-WORK-Straining-Unbl...     4.2         2,637
# 4  https://www.amazon.in/Zuvexa-Sharpener-Profess...     4.3           396
# 5  https://www.amazon.in/Prestige-Omega-Select-No...     4.4         9,877
# 6  https://www.amazon.in/Prestige-Svachh-Deluxe-S...     4.3        20,659
#
#   discount_price actual_price
# 0           ₹349       ₹1,899
# 1           ₹479         ₹999
# 2         ₹1,995       ₹3,995
# 3           ₹154         ₹499
# 4           ₹289         ₹599
# 5         ₹1,170       ₹1,190
# 6         ₹2,382       ₹2,480

# %%
file.shape
# Out:
# (2232, 9)

# %%
file.isna().sum()
# Out:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings            94
# no_of_ratings      94
# discount_price    147
# actual_price       12
# dtype: int64

# %%
file.nunique()
# Out:
# name              2140
# main_category        1
# sub_category         2
# image             2176
# link              2232
# ratings             36
# no_of_ratings      831
# discount_price     717
# actual_price       521
# dtype: int64

# %%
file.columns
# Out:
# Index(['name', 'main_category', 'sub_category', 'image', 'link', 'ratings',
#        'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='object')

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232 entries, 0 to 2231
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2232 non-null   object
#  1   main_category   2232 non-null   object
#  2   sub_category    2232 non-null   object
#  3   image           2232 non-null   object
#  4   link            2232 non-null   object
#  5   ratings         2138 non-null   object
#  6   no_of_ratings   2138 non-null   object
#  7   discount_price  2085 non-null   object
#  8   actual_price    2220 non-null   object
# dtypes: object(9)
# memory usage: 157.1+ KB

# %%
file["discount_price"] = file["discount_price"].str.replace("₹","")
file["actual_price"] = file["actual_price"].str.replace("₹","")

# %%
file['discount_price'] = file["discount_price"].str.replace(',', '').astype(float)
file["actual_price"] = file["actual_price"].str.replace(',', '').astype(float)

# %%
file['ratings'].unique()
# Out:
# array(['4.3', '4', '4.2', '4.4', '4.5', '3.6', '4.1', '3.9', '3.7', '3.8',
#        '4.7', '4.6', '3.5', '5', 'Get', '3.3', nan, '4.8', '3.1', '3',
#        '2.9', '2.8', '3.4', '3.2', '4.9', '1.3', '2.5', '2.2', '2.6',
#        '2.7', '1', '1.5', '2.4', '2', '2.1', '1.8', '2.3'], dtype=object)

# %%
file['ratings']=file['ratings'].replace(['Get'], 0.0)
file['ratings']=file['ratings'].astype(float)

# %%
file['ratings'].unique()
# Out:
# array([4.3, 4. , 4.2, 4.4, 4.5, 3.6, 4.1, 3.9, 3.7, 3.8, 4.7, 4.6, 3.5,
#        5. , 0. , 3.3, nan, 4.8, 3.1, 3. , 2.9, 2.8, 3.4, 3.2, 4.9, 1.3,
#        2.5, 2.2, 2.6, 2.7, 1. , 1.5, 2.4, 2. , 2.1, 1.8, 2.3])

# %%
file['no_of_ratings'] = file['no_of_ratings'].astype(str)
file['correct_no_of_ratings'] = pd.Series([file['no_of_ratings'][x][0].isdigit() for x in range(len(file['no_of_ratings']))])

# Drop columns with incorrect 'no_of_ratings'
file = file[file['correct_no_of_ratings'] == True]
file['correct_no_of_ratings'].value_counts()
# Out:
# True    2127
# Name: correct_no_of_ratings, dtype: int64

# %%
file["no_of_ratings"] = file["no_of_ratings"].str.replace(',', '').astype(float)

# %%
file.head()
# Out:
#                                                 name   main_category  \
# 0  Kitchwell Kitchen Accessories Items | 1100 ML ...  home & kitchen
# 1  Bulfyss Multipurpose 45cm x 5m Super Strong EV...  home & kitchen
# 2  Pigeon By Stovekraft All in One Super Cooker A...  home & kitchen
# 3  STAR WORK Muslin Cloth 1 X 1.2 Meter Cotton fo...  home & kitchen
# 4  Zuvexa 3 Slot Knife Sharpener Professional Kit...  home & kitchen
#
#        sub_category                                              image  \
# 0  Kitchen & Dining  https://m.media-amazon.com/images/I/81Jf-Gz8hO...
# 1  Kitchen & Dining  https://m.media-amazon.com/images/I/61iCTMUVtE...
# 2  Kitchen & Dining  https://m.media-amazon.com/images/I/51OhGq1Y8T...
# 3  Kitchen & Dining  https://m.media-amazon.com/images/I/81fTL+GEuL...
# 4  Kitchen & Dining  https://m.media-amazon.com/images/I/71p6rKdaoq...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Kitchwell-Accessories-Co...      4.3           37.0
# 1  https://www.amazon.in/Bulfyss-Multipurpose-Tex...      4.3         6484.0
# 2  https://www.amazon.in/Pigeon-Stovekraft-Cerami...      4.0         4321.0
# 3  https://www.amazon.in/STAR-WORK-Straining-Unbl...      4.2         2637.0
# 4  https://www.amazon.in/Zuvexa-Sharpener-Profess...      4.3          396.0
#
#    discount_price  actual_price  correct_no_of_ratings
# 0           349.0        1899.0                   True
# 1           479.0         999.0                   True
# 2          1995.0        3995.0                   True
# 3           154.0         499.0                   True
# 4           289.0         599.0                   True

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2127 entries, 0 to 2231
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   2127 non-null   object
#  1   main_category          2127 non-null   object
#  2   sub_category           2127 non-null   object
#  3   image                  2127 non-null   object
#  4   link                   2127 non-null   object
#  5   ratings                2127 non-null   float64
#  6   no_of_ratings          2127 non-null   float64
#  7   discount_price         1986 non-null   float64
#  8   actual_price           2117 non-null   float64
#  9   correct_no_of_ratings  2127 non-null   bool
# dtypes: bool(1), float64(4), object(5)
# memory usage: 168.2+ KB

# %%
file['ratings'].describe()
# Out:
# count    2127.000000
# mean        4.057922
# std         0.475794
# min         1.000000
# 25%         3.900000
# 50%         4.100000
# 75%         4.300000
# max         5.000000
# Name: ratings, dtype: float64

# %%
file=file.dropna(subset=['actual_price','discount_price'])

# %%
file['manufacturer']=file['name'].str.split(' ').str[0]
cols=file.columns.tolist()
# change the position of manufracturer
cols=['name',
 'manufacturer',
 'main_category',
 'sub_category',
 'image',
 'link',
 'ratings',
 'no_of_ratings',
 'discount_price',
 'actual_price',
 'correct_no_of_ratings']
file=file[cols]
file.head()
# Out:
#                                                 name manufacturer  \
# 0  Kitchwell Kitchen Accessories Items | 1100 ML ...    Kitchwell
# 1  Bulfyss Multipurpose 45cm x 5m Super Strong EV...      Bulfyss
# 2  Pigeon By Stovekraft All in One Super Cooker A...       Pigeon
# 3  STAR WORK Muslin Cloth 1 X 1.2 Meter Cotton fo...         STAR
# 4  Zuvexa 3 Slot Knife Sharpener Professional Kit...       Zuvexa
#
#     main_category      sub_category  \
# 0  home & kitchen  Kitchen & Dining
# 1  home & kitchen  Kitchen & Dining
# 2  home & kitchen  Kitchen & Dining
# 3  home & kitchen  Kitchen & Dining
# 4  home & kitchen  Kitchen & Dining
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/81Jf-Gz8hO...
# 1  https://m.media-amazon.com/images/I/61iCTMUVtE...
# 2  https://m.media-amazon.com/images/I/51OhGq1Y8T...
# 3  https://m.media-amazon.com/images/I/81fTL+GEuL...
# 4  https://m.media-amazon.com/images/I/71p6rKdaoq...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Kitchwell-Accessories-Co...      4.3           37.0
# 1  https://www.amazon.in/Bulfyss-Multipurpose-Tex...      4.3         6484.0
# 2  https://www.amazon.in/Pigeon-Stovekraft-Cerami...      4.0         4321.0
# 3  https://www.amazon.in/STAR-WORK-Straining-Unbl...      4.2         2637.0
# 4  https://www.amazon.in/Zuvexa-Sharpener-Profess...      4.3          396.0
#
#    discount_price  actual_price  correct_no_of_ratings
# 0           349.0        1899.0                   True
# 1           479.0         999.0                   True
# 2          1995.0        3995.0                   True
# 3           154.0         499.0                   True
# 4           289.0         599.0                   True

# %%
file[['actual_price','manufacturer']].groupby('manufacturer').mean().round(2).sort_values(by='actual_price',ascending=False)
# Out:
#               actual_price
# manufacturer
# Instant            24900.0
# Wellspire          20199.0
# Vidiem             17384.0
# BlowHot            11990.0
# Elica              11490.0
# ...                    ...
# Self                 179.0
# Freshee              162.0
# Tulips               152.0
# Trokopoka            140.0
# Crystal               75.0
#
# [1100 rows x 1 columns]

# %%
file['discount']=file['actual_price']-file['discount_price']
file['discount_percentage']=round((1-file['discount']/file['actual_price']),2)
file.head()
# Out:
#                                                 name manufacturer  \
# 0  Kitchwell Kitchen Accessories Items | 1100 ML ...    Kitchwell
# 1  Bulfyss Multipurpose 45cm x 5m Super Strong EV...      Bulfyss
# 2  Pigeon By Stovekraft All in One Super Cooker A...       Pigeon
# 3  STAR WORK Muslin Cloth 1 X 1.2 Meter Cotton fo...         STAR
# 4  Zuvexa 3 Slot Knife Sharpener Professional Kit...       Zuvexa
#
#     main_category      sub_category  \
# 0  home & kitchen  Kitchen & Dining
# 1  home & kitchen  Kitchen & Dining
# 2  home & kitchen  Kitchen & Dining
# 3  home & kitchen  Kitchen & Dining
# 4  home & kitchen  Kitchen & Dining
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/81Jf-Gz8hO...
# 1  https://m.media-amazon.com/images/I/61iCTMUVtE...
# 2  https://m.media-amazon.com/images/I/51OhGq1Y8T...
# 3  https://m.media-amazon.com/images/I/81fTL+GEuL...
# 4  https://m.media-amazon.com/images/I/71p6rKdaoq...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Kitchwell-Accessories-Co...      4.3           37.0
# 1  https://www.amazon.in/Bulfyss-Multipurpose-Tex...      4.3         6484.0
# 2  https://www.amazon.in/Pigeon-Stovekraft-Cerami...      4.0         4321.0
# 3  https://www.amazon.in/STAR-WORK-Straining-Unbl...      4.2         2637.0
# 4  https://www.amazon.in/Zuvexa-Sharpener-Profess...      4.3          396.0
#
#    discount_price  actual_price  correct_no_of_ratings  discount  \
# 0           349.0        1899.0                   True    1550.0
# 1           479.0         999.0                   True     520.0
# 2          1995.0        3995.0                   True    2000.0
# 3           154.0         499.0                   True     345.0
# 4           289.0         599.0                   True     310.0
#
#    discount_percentage
# 0                 0.18
# 1                 0.48
# 2                 0.50
# 3                 0.31
# 4                 0.48

# %%
# Import the plotly.express module and assign it to px
import plotly.express as px

# Alternatively, use the full name plotly.express
import plotly.express

# The rest of your code is unchanged
values=file['manufacturer'].value_counts().keys().tolist()[:15]
counts=file['manufacturer'].value_counts().tolist()[:15]
counts,values

plt = px.bar(file, x=values, y=counts, color_discrete_sequence=['RED']*len(file))

plt.update_layout(
        plot_bgcolor='WHITE',
        xaxis_title='Name of The Brand',
        yaxis_title='Count',
        title='<b>Popular Electronics Brands</b>'
)

plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eda5d432-3c1c-48c4-8b2d-f6a457df760a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eda5d432-3c1c-48c4-8b2d-f6a457df760a")) {                    Plotly.newPlot(                        "eda5d432-3c1c-48c4-8b2d-f6a457df760a",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"RED","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Milton","Cello","Amazon","Kuber","Tupperware","Prestige","Borosil","Signoraware","Pigeon","Plantex","Treo","The","Femora","Sumeet","Vinod"],"xaxis":"x","y":[64,63,62,43,33,24,23,19,18,17,16,14,12,12,10],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","s ...

# %%
file[file['discount']==file['discount'].min()]
# Out:
#                                                    name manufacturer  \
# 63    E-COSMOS Airtight Transparent Plastic Lock Foo...     E-COSMOS
# 580                    sujata motor megaflow jar, 2.5 l       sujata
# 755   Coze Food Wrapping Paper Roll (length 20 metre...         Coze
# 1663  Milton Cubic Big Inner Stainless Steel Tiffin ...       Milton
#
#        main_category                  sub_category  \
# 63    home & kitchen              Kitchen & Dining
# 580   home & kitchen              Kitchen & Dining
# 755   home & kitchen              Kitchen & Dining
# 1663  home & kitchen  Kitchen Storage & Containers
#
#                                                   image  \
# 63    https://m.media-amazon.com/images/I/71MdDAgNAr...
# 580   https://m.media-amazon.com/images/I/4140Wm7LMu...
# 755   https://m.media-amazon.com/images/I/61WU5vy1hA...
# 1663  https://m.media-amazon.com/images/I/71zc4Z-+Dj...
#
#                                                    link  ratings  \
# 63    https://www.amazon.in/COSMOS-Airtight-Transpar...      4.1
# 580   https://www.amazon.in/Sujata-Megaflow-Litres-W...      4.3
# 755   https://www.amazon.in/Wrapping-Microwave-Biode...      4.2
# 1663  https://www.amazon.in/Milton-Cubic-Tiffin-1100...      3.7
#
#       no_of_ratings  discount_price  actual_price  correct_no_of_ratings  \
# 63            206.0           198.0         199.0                   True
# 580           195.0          1389.0        1390.0                   True
# 755           126.0           199.0         200.0                   True
# 1663           62.0           614.0         615.0                   True
#
#       discount  discount_percentage
# 63         1.0                 0.99
# 580        1.0                 1.00
# 755        1.0                 1.00
# 1663       1.0                 1.00

# %%
file[file['actual_price']==file['actual_price'].max()]
# Out:
#                                                   name manufacturer  \
# 353  Instant Pot Duo Plus60 9-in-1 Stainless Steel ...      Instant
#
#       main_category      sub_category  \
# 353  home & kitchen  Kitchen & Dining
#
#                                                  image  \
# 353  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                   link  ratings  \
# 353  https://www.amazon.in/Instant-Pot-Duo-Multi-Fu...      4.7
#
#      no_of_ratings  discount_price  actual_price  correct_no_of_ratings  \
# 353        36016.0         11999.0       24900.0                   True
#
#      discount  discount_percentage
# 353   12901.0                 0.48

# %%
manufacturing_rating=file.groupby('manufacturer')['ratings'].mean()
top_manufacturer=manufacturing_rating.sort_values(ascending=False).head(50)
print(top_manufacturer)
# Out:
# manufacturer
# Reinvention    5.0
# ROLLYWARE      5.0
# Docsir         5.0
# GIFT           5.0
# AMRANI         5.0
# CITY           5.0
# HaappyBox      5.0
# Hand           5.0
# Wonder         5.0
# MUKE           5.0
# ARUHIU         5.0
# ShubhKraft     5.0
# FAYBY          5.0
# ZXN            5.0
# GLOBE1         5.0
# GLNRAM         5.0
# SCHIV          5.0
# EVILLVE        5.0
# Scizor         5.0
# DIVYA          5.0
# FOMQUAZLI      5.0
# Ala            5.0
# SHOP           5.0
# All            5.0
# Ashlo's        5.0
# MGNLR          5.0
# K2C            5.0
# MINISO         5.0
# XXSSIER        5.0
# HurryShoppy    5.0
# RAJMAAN        5.0
# MUAC           5.0
# KRISHTAL       5.0
# Wellxo®        5.0
# BERGNER        5.0
# STOVIGLIE      5.0
# Enviro         5.0
# Cracker        5.0
# Varmora        5.0
# 250ml          5.0
# Global         5.0
# JAYTIK         5.0
# Nymbus         5.0
# Cassarina      5.0
# HENNOX         5.0
# HOUSEHOLD      5.0
# TEX-RO         5.0
# Ritmo          5.0
# BOXY           5.0
# Non-Stick      5.0
# Name: ratings, dtype: float64

# %%
sel_cols=['manufacturer','ratings']
new_ds=file[sel_cols]
new_ds
# Out:
#      manufacturer  ratings
# 0       Kitchwell      4.3
# 1         Bulfyss      4.3
# 2          Pigeon      4.0
# 3            STAR      4.2
# 4          Zuvexa      4.3
# ...           ...      ...
# 2227       Aafeen      3.8
# 2228        Cello      5.0
# 2229       HOKIPO      5.0
# 2230          DPM      3.5
# 2231       Crasta      4.1
#
# [1986 rows x 2 columns]

# %%
new_ds1=new_ds.groupby('manufacturer')
new_ds1.mean()
# Out:
#               ratings
# manufacturer
# (Pack           4.100
# 100             4.000
# 12FOR           3.775
# 1500ml          4.300
# 16PCs           4.300
# ...               ...
# victorex        3.800
# we3             4.100
# wolpin          4.040
# zebzo           4.000
# |PACK           3.000
#
# [1100 rows x 1 columns]

# %%
manufacturer_name=values
filtered_ds=new_ds[new_ds['manufacturer'].isin(manufacturer_name)]

print(filtered_ds)
filtered_ds['manufacturer'].unique()
# Out:
#      manufacturer  ratings
# 2          Pigeon      4.0
# 5        Prestige      4.4
# 6        Prestige      4.3
# 7            Treo      4.3
# 9          Amazon      4.3
# ...           ...      ...
# 2163        Cello      3.0
# 2174        Cello      4.4
# 2183       Milton      4.3
# 2194        Cello      4.1
# 2228        Cello      5.0
#
# [430 rows x 2 columns]
# array(['Pigeon', 'Prestige', 'Treo', 'Amazon', 'Cello', 'Milton', 'Kuber',
#        'Signoraware', 'Plantex', 'Vinod', 'Tupperware', 'The', 'Borosil',
#        'Sumeet', 'Femora'], dtype=object)

# %%
new_ds1=filtered_ds.groupby('manufacturer')
new_ds1.mean()
# Out:
#                ratings
# manufacturer
# Amazon        4.116129
# Borosil       4.200000
# Cello         4.073016
# Femora        4.283333
# Kuber         4.041860
# Milton        4.043750
# Pigeon        3.627778
# Plantex       4.188235
# Prestige      4.062500
# Signoraware   4.315789
# Sumeet        4.116667
# The           4.007143
# Treo          4.325000
# Tupperware    4.239394
# Vinod         4.020000
